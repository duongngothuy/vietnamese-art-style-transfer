# %% [markdown]
# # Disparities in Access: Mental Health Resources Across Income Levels in California
#
# # Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [ X ] YES - make available
# * [  ] NO - keep private
#
# # Names
#
# - Aileen Phuong
# - Arohan Mittal
# - Genevieve Selsor
# - Duong Ngo
# - Ryan Christian Nalangan
#
# # Link to Video
#
# https://drive.google.com/file/d/1j067VN79sacm998NGWz5qtBcVntNqjlZ/view?usp=sharing
#
# # Abstract
#
# Access to mental health care is an important issue in California, where the difference in economic resources may affect the availability of mental health providers and services. This project aims to explore the correlation between different income levels, both low and high household income levels and their access to mental health care across different zip codes, focusing on access to psychologists, the capacity of related facilities, and the range of health care products.
#
# Our analysis began by cleaning and merging multiple datasets. We used the following datasets as indicators for general income level in a neighbourhood: Area Median Income (AMI) data from 2022 and 2023, California 2023 5-Year Estimate Census, and California zip codes. Next, to analyse the availability of different mental healthcare services we used the following datasets: licensing records for psychologists in California, count of available health care products, and facility capacity data by zip code. Using statistical tests and visualizations such as density plots, heatmaps, scatterplots, best fit lines, and t-test analysis, we investigated how income correlates with mental health care availability and quality indicators.
#
# Our findings indicate a generally positive correlation between higher income areas and greater availability of psychologists as well as mental health products. Zip codes and counties with higher median household incomes tend to have more licensed psychologists and a higher count of mental health products being offered. However, the relationship is not perfectly linear, as there are many other contributing factors that likely influence access to mental health care. Our different datasets have consistent but modest correlations, suggesting that income is an important factor but not the only factor impacting the inequalities.
#
# While the difference in income levels do influence access to mental health care, addressing the availability of mental health access requires a more comprehensive approach to understand the mental health access and must consider a large range of factors, not only household income per zip code. Moreover, this study also highlights the importance and need for ethical consideration in handling sensitive data such as socioeconomic and health-related data to avoid misinterpretation or reinforcing stereotypes.

# %% [markdown]
# # Research Question

# %% [markdown]
# How does access to mental health care–including therapists, facilities, and insurance coverage–differ between high-income and low-income neighborhoods across California?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Mental health care is an essential component of health care, but it is still one of the most neglected areas within the U.S. healthcare system. Millions of people in the U.S. experience many different mental health conditions every year, with those conditions ranging from anxiety disorders, depression, or PTSD, and that experience is different for everyone, especially for marginalized communities. Communities of a lower socioeconomic status are more likely to be at the higher end of barriers due to their lower income status. These barriers can range in cost, not having a provider in their community, no insurance or underinsured, and long wait times for care or treatment. Because of this, we are leaving people behind without care and without the support they need when they need it most, further perpetuating and contributing to such health disparities.
#
# Research has repeatedly established that low-income and minority communities experience unreasonably more difficulty in accessing mental health care. As reported by the Centers for Disease Control and Prevention (CDC), adults living at or below the national poverty level are more likely to report frequent mental distress; but they are also the least likely to receive adequate treatment.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) The National Alliance for Mental Illness (NAMI) reports that many providers will not accept public insurance programs (e.g. Medicaid) that are often used by low-income populations.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) Additionally, there are treatment access disparities for racial and ethnic minorities that were limited for Latinx, Asians, and Black communities, as demonstrated in a study in 2018 by Alegría et al., which highlighted notable barriers in access to treatment that are tied to distance and economy.<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3)
#
# Even if these studies indicate widespread equality, research has mostly focused on broad inequalities or large-scale statistics. Despite those sources that indicate neighborhood-level inequalities, especially urban environments that can differ from communities to communities, there does not appear to be much research that compares access at the neighborhood level. Access to care can vary dramatically depending on income level, zoning laws, and clinic location. Our project aims to complete a purpose that compares mental health resources in low-income neighborhoods to high-income neighborhoods using publicly available data. By investigating issues including number of providers, provider acceptance of insurance, and more specific variables in the project, this analysis hopes to contribute to a more practical understanding of access to mental health resources at a local level.<a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4)
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) CDC. (2021). Mental Health Data and Publications. https://www.cdc.gov/mentalhealth/data_publications/index.htm
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) NAMI. (2020). Access to Mental Health Care. https://www.nami.org/Advocacy/Policy-Priorities/Access-to-Mental-Health-Care
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Alegría, M., et al. (2018). Disparities in access to mental health treatment: Results from the National Latino and Asian American Study. Psychiatric Services, 59(11)
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) APA. (2022). Disparities in Mental Health. https://www.apa.org/monitor/2022/07/disparities-mental-health

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Our hypothesis is that lower-income neighborhoods in California will have significantly less access to mental health resources compared to higher-income neighborhoods. We expect that there will be fewer licensed mental health providers per capita, lower availability of health insurance, and a correlation between provider distribution and neighborhood income levels. These disparities are caused by the tendency of mental health providers to cluster in wealthier areas, where patients are more likely to have private insurance or the ability to pay out-of-pocket, which causes a barrier of mental health care in low-income communities.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data overview
#
# For each dataset include the following information
# - Dataset #1
#   - Dataset Name: California Zip Codes
#   - Link to the dataset: https://worldpopulationreview.com/zips/california
#   - Number of observations: 1,802
#   - Number of variables: 3 (zip code, city, county)
# - Dataset #2
#   - Dataset Name: 2023 American Community Survey 5-Year Estimate
#   - Link to the dataset: https://www.census.gov/data/developers/data-sets/acs-5year.html
#   - Number of observations: 1,593
#   - Number of variables: 5 (population total, zip code, median household income, city, county)
# - Dataset #3
#   - Dataset Name: California County Income Limits
#   - Link to the dataset: https://data.ca.gov/dataset/income-limits-by-county
#   - Number of observations: 116
#   - Number of variables: 34 (Area Median Income (AMI), and income limits across different household sizes (1-8 persons) at Acutely Low Income (ALI), Extremely Low Income (ELI), Very Low Income (VLI), Low Income (LI), and Moderate Income (MOD) levels).
# - Dataset #4
#   - Dataset Name: Psychologists by Zip Code, County in California
#   - Link to the dataset: https://www.dca.ca.gov/consumers/public_info/index.shtml
#   - Number of observations: 2002
#   - Number of variables: 3 (zip, county, and psychologist_count)
# - Dataset #5
#   - Dataset Name: Covered California 2025 Products by Zip Code
#   - Link to the dataset: https://hbex.coveredca.com/data-research/
#   - Number of observations: 2,694
#   - Number of variables: 3 Variables (zip code, county, healthcare options (16 health care providers))
# - Dataset #6
#   - Dataset Name: California Licensed MHRCs and PHFs
#   - Link to the dataset: https://data.chhs.ca.gov/dataset/272b9ce1-1bcf-4bf4-8294-ab3704b79608/resource/ef9f4daf-892c-45f6-b46a-3037c5a93b23/download/mhls-mhrc-phf-facilities-april-2025.csv
#   - Number of observations: 72
#   - Number of variables: 20
#
# Dataset #1 is indexed by all unique California zip codes, with each zip code containing the city and county it's in along with its population. This is essential in our analysis as we plan to use zip codes to differentiate between neighborhoods throughout the state. Since a few of the datasets we have include zip codes throughout the country, this dataset serves to filter our other datasets to only include California zip codes.
#
# Dataset #2 contains numerous different demographics collected in the 2023 American Community Survey 5-Year Estimate by the U.S. Census Bureau. In this dataset, we only plan to use the median household income and total population variables, indexed by zip code. This dataset serves as our primary source for collecting median household income by zip codes, and will be combined with most of our other datasets.
#
# For Dataset #3, the dataset contains income limit thresholds for each of California’s 58 counties for the years 2022 and 2023. Key variables include the Area Median Income (AMI), and income limits across different household sizes (1-8 persons) at Acutely Low Income (ALI), Extremely Low Income (ELI), Very Low Income (VLI), Low Income (LI), and Moderate Income (MOD) levels. All values are integers. The dataset will need cleaning to standardize column names across years, and possibly merge both years into one tidy DataFrame for comparison.
#
# Dataset #4 contains licensing information from psychologists, gathered from California Department of Consumer Affairs. Key variables from this dataset include their License Type , Zip Code, County, and State. This dataset will be used to gather data on how many psychologists are located near a variety of zip codes. It has a mix of categorical and string data types. This dataset was cleaned to filter out the different license types so that we only keep people that are Psychologists. We also filtered it to only keep data from psychologists within California, trimmed the zip codes to standardized 5-digit formats, and renamed column names to their lowercase counterparts. The groupby function was used in order to get a count of all psychologists located within/near the different zip codes. A visual was made to better visualize the number of psychologists between the different zip codes and counties.
#
# Dataset #5 consists of data gathered from Covered California products offered by zip code, we gain data on how many health insurance plans are available per zip code in california. This dataset will be used to analyze potential correlations between household income and the availability of health insurance plans by ZIP code. The data provided by Covered California by zip code, included duplicate zip codes as many zip codes are shared across two counties, in order to not count duplicates, the data was cleaned of duplicates, the zip codes provided also includes PO Box-only areas which will also need to be cleaned using one of our other databases list of CA zip codes. In order to clean the zip codes of PO Boxes, we will be combining with dataset 6 and using only California zip codes. These datasets will be combined with other datasets using zip codes across California.
#
# For Dataset #6: The goal of this dataset is to provide a validation check for our main therapist dataset. To this end, we are counting total patient capacity in mental health institutions within each county in california. These counties serve as bins for our zip codes, since our research question is based on zip codes. Along the way, we drop any unnecessary variables. Since county data is not available within dataset#6, we also use dataset#1 as a supporting dataframe to provide zipcode-to-county data. We merge this data by zipcode and group by county to find the total patient capacity for each county, and then merge with the supporting dataframe again so that each zipcode (whether it was in original dataframe or not) is associated with its associated county’s total patient capacity.

# %% [markdown]
# ## Dataset #1: California Zip Codes

# %%
import pandas as pd
import numpy as np
import requests as re
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')
from scipy.stats import ttest_ind

# %%
ca_zipcodes = pd.read_csv('data/cazipcodes.csv')
ca_zipcodes = ca_zipcodes[['zip', 'city', 'county']]
ca_zipcodes['zip'] = ca_zipcodes['zip'].astype(int)
ca_zipcodes
# Out:
#         zip              city                 county
# 0     90011       Los Angeles     Los Angeles County
# 1     90650           Norwalk     Los Angeles County
# 2     94565         Pittsburg    Contra Costa County
# 3     92336           Fontana  San Bernardino County
# 4     91331           Pacoima     Los Angeles County
# ...     ...               ...                    ...
# 1797  95915            Belden          Plumas County
# 1798  95929             Chico           Butte County
# 1799  95958            Nelson           Butte County
# 1800  96061        Mill Creek          Tehama County
# 1801  96155  South Lake Tahoe       El Dorado County
#
# [1802 rows x 3 columns]

# %% [markdown]
# ## Dataset #2: 2023 American Community Survey 5-Year Estimate

# %%
# collect population data and median household income indexed by zip codes from US 2023 ACS 5-year data API

data = re.get(f'https://api.census.gov/data/2023/acs/acs5?get=B01003_001E,B19013_001E&for=zip%20code%20tabulation%20area:*&key=3c64d895f18a7dc61b53f1482d7c9d8b12ea4fe7')
data_json = data.json()

# %%
# format data into dataframe

def df_clean_up(df):
    df = df.rename(columns={'B01003_001E': 'population_total',
                            'B19013_001E': 'median_hh_income_total',
                            'zip code tabulation area': 'zip_code'})
    
    df['zip_code'] = df['zip_code'].astype(int) #convert zip codes to integers
    df['population_total'] = df['population_total'].astype(int).replace(0, np.nan) # replaced populations of 0 with null
    df['median_hh_income_total'] = df['median_hh_income_total'].astype(int).replace(-666666666.0, np.nan) # replaced missing incomes with null

    return df

df = pd.DataFrame(data_json[1:], columns=data_json[0]).pipe(df_clean_up)
df
# Out:
#        population_total  median_hh_income_total  zip_code
# 0               16721.0                 18571.0       601
# 1               37510.0                 21702.0       602
# 2               48317.0                 19243.0       603
# 3                5435.0                 20226.0       606
# 4               25413.0                 23732.0       610
# ...                 ...                     ...       ...
# 33767              25.0                     NaN     99923
# 33768             854.0                 60000.0     99925
# 33769            1385.0                 69464.0     99926
# 33770              18.0                     NaN     99927
# 33771            2105.0                 64659.0     99929
#
# [33772 rows x 3 columns]

# %%
# merge california zip codes with US data

zip_data = df.merge(ca_zipcodes, left_on='zip_code', right_on='zip', how='inner')
zip_data = zip_data.drop(columns=['zip'])
zip_data = zip_data[zip_data['median_hh_income_total'].isna() == False] #dropped zip codes without median household income info (209 values)
zip_data = zip_data.set_index('zip_code')
zip_data
# Out:
#           population_total  median_hh_income_total              city  \
# zip_code
# 90001              56403.0                 60751.0       Los Angeles
# 90002              52735.0                 56158.0       Los Angeles
# 90003              71708.0                 54781.0       Los Angeles
# 90004              58844.0                 62655.0       Los Angeles
# 90005              38747.0                 52755.0       Los Angeles
# ...                    ...                     ...               ...
# 96145               3291.0                121875.0        Tahoe City
# 96146               1120.0                114145.0    Olympic Valley
# 96148                462.0                 82692.0       Tahoe Vista
# 96150              29527.0                 83738.0  South Lake Tahoe
# 96161              19231.0                128535.0           Truckee
#
#                       county
# zip_code
# 90001     Los Angeles County
# 90002     Los Angeles County
# ...

# %% [markdown]
# ## Dataset #3: California County Income Limits

# %%
# Load datasets
df_2022 = pd.read_csv("data/2022-income-limits.csv")
df_2023 = pd.read_csv("data/2023-income-limits.csv")

# Preview
print(df_2022.shape)
print(df_2023.shape)
df_2022.head()
# Out:
# (58, 42)
# (58, 42)
#       County     AMI  ALI_1  ALI_2  ALI_3  ALI_4  ALI_5  ALI_6  ALI_7  ALI_8  \
# 0    Alameda  142800  15000  17100  19250  21400  23100  24800  26550  28250
# 1     Alpine   94900  10000  11400  12850  14250  15400  16550  17650  18800
# 2     Amador   86600   9100  10400  11700  13000  14050  15100  16100  17150
# 3      Butte   85000   8950  10200  11500  12750  13750  14800  15800  16850
# 4  Calaveras   90000   9450  10800  12150  13500  14600  15650  16750  17800
#
#    ...    LI_7    LI_8   MOD_1   MOD_2   MOD_3   MOD_4   MOD_5   MOD_6  \
# 0  ...  135950  144700  119950  137100  154200  171350  185050  198750
# 1  ...   90100   95900   79750   91100  102500  113900  123000  132100
# 2  ...   85950   91500   72750   83100   93500  103900  112200  120500
# 3  ...   77300   82250   71400   81600   91800  102000  110150  118300
# 4  ...   89300   95050   75600   86400   97200  108000  116650  125300
#
#     MOD_7   MOD_8
# 0  212450  226200
# ...

# %%
# Check if column names match between datasets
columns_match = (df_2022.columns == df_2023.columns).all()
print(f"Do the columns match? {columns_match}")


# If they match, proceed to add Year column and combine
if columns_match:
   df_2022['Year'] = 2022
   df_2023['Year'] = 2023


   # Combine datasets
   df_combined = pd.concat([df_2022, df_2023], ignore_index=True)


   # Preview combined dataset
   print(f"Combined dataset shape: {df_combined.shape}")
   display(df_combined.head())


   # Check for missing values
   missing_values = df_combined.isna().sum().sum()
   print(f"Total missing values in combined dataset: {missing_values}")
else:
   print("Warning: Column names do not match. Check datasets before combining.")
# Out:
# Do the columns match? True
# Combined dataset shape: (116, 43)
#       County     AMI  ALI_1  ALI_2  ALI_3  ALI_4  ALI_5  ALI_6  ALI_7  ALI_8  \
# 0    Alameda  142800  15000  17100  19250  21400  23100  24800  26550  28250
# 1     Alpine   94900  10000  11400  12850  14250  15400  16550  17650  18800
# 2     Amador   86600   9100  10400  11700  13000  14050  15100  16100  17150
# 3      Butte   85000   8950  10200  11500  12750  13750  14800  15800  16850
# 4  Calaveras   90000   9450  10800  12150  13500  14600  15650  16750  17800
#
#    ...    LI_8   MOD_1   MOD_2   MOD_3   MOD_4   MOD_5   MOD_6   MOD_7  \
# 0  ...  144700  119950  137100  154200  171350  185050  198750  212450
# 1  ...   95900   79750   91100  102500  113900  123000  132100  141250
# 2  ...   91500   72750   83100   93500  103900  112200  120500  128850
# 3  ...   82250   71400   81600   91800  102000  110150  118300  126500
# 4  ...   95050   75600   86400   97200  108000  116650  125300  133900
#
# ...

# %% [markdown]
# ## Dataset #4: Therapist by Zip Code in California

# %%
# Read the file
df = pd.read_csv("data/Psychology_Data00.xls", sep='\t')

# %%
# Filter rows to keep only License Type containing Psychologist
psychologists = df[df['License Type'].str.contains('Psychologist', case=False, na=False)]

# Filter to only keep data from those in California 
psychologists_ca = psychologists[psychologists['State'] == 'CA']

# Keep Zip and County columns
df_selected = psychologists_ca[['Zip', 'County']].copy()

# Replace NaN values with string '0'
df_selected = df_selected.fillna('0')

# Keep only the first 5 digits of Zip code as string
df_selected['Zip'] = df_selected['Zip'].astype(str).str[:5]

# Convert column names to lowercase
df_selected.columns = df_selected.columns.str.lower()

# Group by both zip and county, and count number of psychologists
psychologists_by_zip = (
    df_selected.groupby(['zip', 'county'])
    .size()
    .reset_index(name='psychologist_count')
)

# Sort by count descending
psychologists_by_zip = psychologists_by_zip.sort_values(by='psychologist_count', ascending=False)

# Preview
print(psychologists_by_zip)

# Take top 20 rows and make a copy to avoid SettingWithCopyWarning
top_20 = psychologists_by_zip.head(20).copy()

# Create combined label for zip and county
top_20['zip_county'] = top_20['zip'] + ', ' + top_20['county']

# Plot
plt.figure(figsize=(12,8))
plt.barh(top_20['zip_county'], top_20['psychologist_count'], color='skyblue')
plt.xlabel('Number of Psychologists')
plt.ylabel('Zip Codes, County')
plt.title('Top 20 California ZIP Code + County Areas by Number of Psychologists')
plt.gca().invert_yaxis()  # largest bars on top
plt.tight_layout()
plt.show()
# Out:
#         zip          county  psychologist_count
# 34    90025     LOS ANGELES                 216
# 852   92660          ORANGE                 185
# 271   91101     LOS ANGELES                 162
# 1286  94115   SAN FRANCISCO                 155
# 1328  94304     SANTA CLARA                 150
# ...     ...             ...                 ...
# 1034  93222     LOS ANGELES                   1
# 1038  93243            KERN                   1
# 1039  93245          FRESNO                   1
# 1043  93263            KERN                   1
# 2001  99999  SAN BERNARDINO                   1
#
# [2002 rows x 3 columns]

# %% [markdown]
# ## Dataset #5: Covered California 2025 Products by Zip Code

# %%
#Read Covered California health insurance by zip code csv file into dataframe
path = 'data/CAProductByZip.csv'
data = pd.read_csv(path)
data
# Out:
#       Covered California Rating Region     County  FIPS County Code  Zip Code  \
# 0                                    1     ALPINE                 3     95646
# 1                                    1     ALPINE                 3     96120
# 2                                    1     AMADOR                 5     95601
# 3                                    1     AMADOR                 5     95629
# 4                                    1     AMADOR                 5     95640
# ...                                ...        ...               ...       ...
# 2688                                19  SAN DIEGO                73     92195
# 2689                                19  SAN DIEGO                73     92196
# 2690                                19  SAN DIEGO                73     92197
# 2691                                19  SAN DIEGO                73     92198
# 2692                                19  SAN DIEGO                73     92199
#
# ...

# %%
#Remove duplicate zip codes from county's that share zip codes
data_unique = data.drop_duplicates(subset="Zip Code", keep="first")

#Change both zip code columns to have the same format
data_unique['Zip Code'] = data_unique['Zip Code'].astype(int)
ca_zipcodes['zip'] = ca_zipcodes['zip'].astype(int)

#rename zip column in ca_zipcodes to match data
data2_renamed = ca_zipcodes.rename(columns={'zip': 'Zip Code'})

#merge on inner "Zip Code" to keep matching zip codes
merge_data = pd.merge(data_unique, data2_renamed, on='Zip Code', how='inner')

merge_data.shape
merge_data
# Out:
# /var/folders/jx/dr80n_1n4s3flx3lb29pzrl00000gn/T/ipykernel_58589/2278182503.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_unique['Zip Code'] = data_unique['Zip Code'].astype(int)
#       Covered California Rating Region     County  FIPS County Code  Zip Code  \
# 0                                    1     ALPINE                 3     95646
# 1                                    1     ALPINE                 3     96120
# 2                                    1     AMADOR                 5     95601
# 3                                    1     AMADOR                 5     95629
# 4                                    1     AMADOR                 5     95640
# ...

# %%
#List of product columns
product_columns = ['Aetna HMO', 'Anthem EPO', 'Anthem HMO', 'Blue Shield HMO', 
                   'Blue Shield PPO', 'Chinese Community HMO', 'Health Net HMO', 
                   'Health Net PPO', 'IEHP HMO', 'Kaiser HMO', 'LA Care HMO', 
                   'Molina HMO', 'Sharp HMO 1 (Copay)', 'Sharp HMO 2 (Coin)']

#When xlsx file is convert to csv file, the 'X's were converted to random numbers 1-9, so they must be replaced
#Replace all non-NaN values in the product columns with 1
merge_data[product_columns] = merge_data[product_columns].notna().astype(int)

#get sum of health products offered per zip code
df_total_products = merge_data.groupby('Zip Code')[product_columns].sum()

#add a new column for the total products offered per Zip Code
df_total_products['Total Products'] = df_total_products.sum(axis=1)

#add a new DataFrame that is for zip code and total products offered per zip code
df_total_products = df_total_products[['Total Products']].reset_index()

print(df_total_products)
# Out:
#       Zip Code  Total Products
# 0        90001               8
# 1        90002               8
# 2        90003               8
# 3        90004               8
# 4        90005               8
# ...        ...             ...
# 1797     96146               3
# 1798     96148               3
# 1799     96150               3
# 1800     96155               3
# 1801     96161               2
#
# [1802 rows x 2 columns]

# %%
#histogram of number of zip codes across number of products offered, kde shows frequency of data
plt.figure(figsize=(10, 6))
sns.histplot(df_total_products['Total Products'], kde=True, bins=30, color='purple')
#sns.histplot(df_total_products['Total Products'], bins=30)

#Labels
plt.xlabel('Total Healthcare Products')
plt.ylabel('Number of Zip Codes')
plt.title('Distribution of Healthcare Products Across Zip Codes')

#show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Dataset #6: California Licensed MHRCs and PHFs

# %%
# reading dataframe and dropping unnecessary variables
df = pd.read_csv('data/FacilityData.csv')
df = df[['Physical Zip','Client/Patient Capacity']]
df.columns = ['zip', 'capacity']
ca_zipcodes = ca_zipcodes[['zip', 'county']]
df
# Out:
#       zip  capacity
# 0   95062        99
# 1   94062        16
# 2   91901       128
# 3   95926        16
# 4   95315        98
# ..    ...       ...
# 67  94062        16
# 68  95062        16
# 69  95307        16
# 70  94578        16
# 71  94578        99
#
# [72 rows x 2 columns]

# %%
# each zipcode should only have a single associated county
assert(ca_zipcodes['zip'].count() == ca_zipcodes['zip'].nunique())
# there are 58 counties in CA
assert(ca_zipcodes['county'].nunique() == 58)

# %%
# Adding county names to df
df = pd.merge(df, ca_zipcodes, on='zip', how='left')

# New dataframe storing counties and associated capacities
df_counter = df.groupby('county')['capacity'].sum().reset_index()

# Adding capacities to all zip codes dataframe
df_zip = pd.merge(ca_zipcodes, df_counter, on='county', how='left')
df_zip['capacity'] = df_zip['capacity'].fillna(0)
df_zip = df_zip.drop(columns=['county'])
df_zip
# Out:
#         zip  capacity
# 0     90011     371.0
# 1     90650     371.0
# 2     94565      16.0
# 3     92336       0.0
# 4     91331     371.0
# ...     ...       ...
# 1797  95915       0.0
# 1798  95929      16.0
# 1799  95958      16.0
# 1800  96061      16.0
# 1801  96155      16.0
#
# [1802 rows x 2 columns]

# %% [markdown]
# # Results
#
# ## Exploratory Data Analysis

# %% [markdown]
# ### Comparing the Number of Psychologists to Zip Code Data
#
# We would first like to examine the distribution of median incomes by zip codes across the state. We can do this by plotting a histogram.

# %%
mean_val   = zip_data['median_hh_income_total'].mean()
median_val = zip_data['median_hh_income_total'].median()

sns.histplot(zip_data, x='median_hh_income_total', kde=False)

# add vertical lines for mean & median
plt.axvline(mean_val,
            color='red',     # line color
            linestyle='--',  # dashed
            linewidth=2,
            label=f'Mean: {mean_val:,.0f}')
plt.axvline(median_val,
            color='blue',    # line color
            linestyle='-.',  # dash-dot
            linewidth=2,
            label=f'Median: {median_val:,.0f}')

# set axis labels & title
plt.xlabel('Median Household Income (USD)', fontsize=12)
plt.ylabel('Count of ZIP Codes',           fontsize=12)
plt.title ('Distribution of Median Household Income by ZIP', fontsize=14)

# add legend
plt.legend(title='Statistics')
plt.tight_layout()
plt.show()

# %% [markdown]
# From our histogram we can see that median incomes by zip code are skewed to the right, hence why the mean of all median incomes by zip code is higher than the median of all median incomes by zip code.

# %% [markdown]
# We then look to discover the distribution of the number of psychologists within a certain zip code.

# %%
mean_val   = psychologists_by_zip['psychologist_count'].mean()
median_val = psychologists_by_zip['psychologist_count'].median()

sns.histplot(psychologists_by_zip, x='psychologist_count', kde=False)

# add vertical lines for mean & median
plt.axvline(mean_val,
            color='red',     # line color
            linestyle='--',  # dashed
            linewidth=2,
            label=f'Mean: {mean_val:,.0f}')
plt.axvline(median_val,
            color='blue',    # line color
            linestyle='-.',  # dash-dot
            linewidth=2,
            label=f'Median: {median_val:,.0f}')

# set axis labels & title
plt.xlabel('Number of Psychologists', fontsize=12)
plt.ylabel('Count of ZIP Codes',           fontsize=12)
plt.title ('Distribution of Number of Psychologists by ZIP', fontsize=14)

# add legend
plt.legend(title='Statistics')
plt.tight_layout()
plt.show()

# %% [markdown]
# As we can see, the histogram is heavily skewed right, with half of our zipcodes having 3 or less psychologists. We can perform a log scale to the x-axis to better see this distribution.

# %%
mean_val   = psychologists_by_zip['psychologist_count'].mean()
median_val = psychologists_by_zip['psychologist_count'].median()

plt.figure(figsize=(10,6))
sns.histplot(psychologists_by_zip,
             x='psychologist_count',
             kde=False)

# add mean & median
plt.axvline(mean_val,   linestyle='--', linewidth=2, color='red', label=f'Mean: {mean_val:,.0f}')
plt.axvline(median_val, linestyle='-.', linewidth=2, color='blue', label=f'Median: {median_val:,.0f}')

# switch the x‐axis to log scale
plt.xscale('log')
# optionally relabel ticks
plt.xticks([1,10,100,1000],
           ['1','10','100','1k'])

plt.xlabel('Number of Psychologists (log scale)', fontsize=12)
plt.ylabel('Count of ZIP Codes',                fontsize=12)
plt.title ('Psychologist Counts by ZIP (Log‐X)', fontsize=14)
plt.legend(title='Statistics')
plt.tight_layout()
plt.show()

# %% [markdown]
# In order to compare the number of psychologists to the zip code data, we must combine the datasets as such:

# %%
psychologists_by_zip_count = psychologists_by_zip.groupby('zip')['psychologist_count'].sum().reset_index()
psychologists_by_zip_count['zip'] = psychologists_by_zip_count['zip'].astype(int)
combined = zip_data.merge(psychologists_by_zip_count, left_index=True, right_on='zip', how='left').set_index('zip').fillna(0)
combined['psychologist_count'] = combined['psychologist_count'].astype(int)
combined
# Out:
#        population_total  median_hh_income_total              city  \
# zip
# 90001           56403.0                 60751.0       Los Angeles
# 90002           52735.0                 56158.0       Los Angeles
# 90003           71708.0                 54781.0       Los Angeles
# 90004           58844.0                 62655.0       Los Angeles
# 90005           38747.0                 52755.0       Los Angeles
# ...                 ...                     ...               ...
# 96145            3291.0                121875.0        Tahoe City
# 96146            1120.0                114145.0    Olympic Valley
# 96148             462.0                 82692.0       Tahoe Vista
# 96150           29527.0                 83738.0  South Lake Tahoe
# 96161           19231.0                128535.0           Truckee
#
#                    county  psychologist_count
# zip
# 90001  Los Angeles County                   0
# 90002  Los Angeles County                   1
# ...

# %% [markdown]
# We can plot a scatter plot of the relationship between the number of psychologists and the total population within a zip code.

# %%
# assume df has: population_total, psychologist_count, income_class
# sns.set_style("whitegrid")

# create the lmplot
g = sns.lmplot(
    data=combined,
    x="population_total",
    y="psychologist_count",
    palette="Set2",
    scatter_kws={"alpha":0.7, "edgecolor": None},
    line_kws={"linewidth":2, "color":'red'},
    height=6,
    aspect=1.3,
)

# relabel ticks for readability
ax = g.ax

# axes labels & title
ax.set_xlabel("Total Population (log scale)", fontsize=12)
ax.set_ylabel("Number of Psychologists (log scale)", fontsize=12)
plt.suptitle("Psychologist Count vs Population", y=1.02, fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# As we can see, it looks like the population and number of psychologists within a zip code have a positive relationship, but it is a bit hard to determine a distinct relationship due to overplotting. Since there is a bit of overplotting towards the bottom of the y-axis, we can use a log scale on the y-axis to better show the data.

# %%
# sns.set_style("whitegrid")

g = sns.lmplot(
    data=combined,
    x="population_total",
    y="psychologist_count",
    scatter_kws={"alpha":0.7, "edgecolor":None},
    line_kws={"linewidth":2, "color":"red"},
    height=6,
    aspect=1.3,
)

# log‐scale axes
g.set(yscale="log")

# tweak tick labels
ax = g.ax
ax.set_yticks([1,10,100,1000])
ax.set_yticklabels(["1","10","100","1k"])

ax.set_xlabel("Total Population")
ax.set_ylabel("Number of Psychologists (log scale)")
plt.suptitle("Psychologist Count vs Population", y=1.02, fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# As we can see from the plot, many zip codes have less than 10 therapists, regardless of their population.

# %% [markdown]
# We can now plot the relationship between the number of psychologists and the median income of each zip code.

# %%
# assume df has: population_total, psychologist_count, income_class
# sns.set_style("whitegrid")

# create the lmplot
g = sns.lmplot(
    data=combined,
    x="median_hh_income_total",
    y="psychologist_count",
    palette="Set2",
    scatter_kws={"alpha":0.7, "edgecolor": None},
    line_kws={"linewidth":2, "color":'red'},
    height=6,
    aspect=1.3,
)

# relabel ticks for readability
ax = g.ax

# axes labels & title
ax.set_xlabel("Median Household Income (USD)", fontsize=12)
ax.set_ylabel("Number of Psychologists", fontsize=12)
plt.suptitle("Psychologist Count vs Median Household Income", y=1.02, fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# After rescaling the y-axis:

# %%
# sns.set_style("whitegrid")

g = sns.lmplot(
    data=combined,
    x="median_hh_income_total",
    y="psychologist_count",
    scatter_kws={"alpha":0.7, "edgecolor":None},
    line_kws={"linewidth":2, "color":"red"},
    height=6,
    aspect=1.3,
)

# log‐scale axes
g.set(yscale="log")

# tweak tick labels
ax = g.ax
ax.set_yticks([1,10,100,1000])
ax.set_yticklabels(["1","10","100","1k"])

ax.set_xlabel("Median Household Income (USD)")
ax.set_ylabel("Number of Psychologists (log scale)")
plt.suptitle("Psychologist Count vs Median Household Income", y=1.02, fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# When plotting the relationship between income and psychologist count, we can see a more apparent trend: lower income zip codes tend to have more psychologist counts under 10 than higher income zip codes do. However, since our data is still overplotted, we can't concretely come to this conclusion.

# %% [markdown]
# Lastly, we can plot the relationship between psychologists per 100,000 residents in an area's zip code compared to the area's median household income.

# %%
combined['psychologists_per_100k'] = combined['psychologist_count'] / combined['population_total'] * 100000

# create the lmplot
g = sns.lmplot(
    data=combined,
    x="median_hh_income_total",
    y="psychologists_per_100k",
    palette="Set2",
    scatter_kws={"alpha":0.7, "edgecolor": None},
    line_kws={"linewidth":2, "color":'red'},
    height=6,
    aspect=1.3,
)

# relabel ticks for readability
ax = g.ax

# axes labels & title
ax.set_xlabel("Median Household Income (USD)", fontsize=12)
ax.set_ylabel("Psychologists per 100k Residents", fontsize=12)
plt.suptitle("Psychologists per 100k Residents vs Median Household Income", y=1.02, fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# Since there are a few large outliers, we will drop them so we can better assess if there is a trend.

# %%
no_outlier = combined[combined['psychologists_per_100k'] < 1000]

g = sns.lmplot(
    data=no_outlier,
    x="median_hh_income_total",
    y="psychologists_per_100k",
    palette="Set2",
    scatter_kws={"alpha":0.7, "edgecolor": None},
    line_kws={"linewidth":2, "color":'red'},
    height=6,
    aspect=1.3,
)

# relabel ticks for readability
ax = g.ax

# axes labels & title
ax.set_xlabel("Median Household Income (USD)", fontsize=12)
ax.set_ylabel("Psychologists per 100k Residents", fontsize=12)
plt.suptitle("Psychologists per 100k Residents vs Median Household Income", y=1.02, fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# After removing outliers, we can see that there is a positive correlation between the number of psychologists per 100k residents and household income, indicating that zipcodes with higher median household incomes have access to more psychologists.

# %% [markdown]
# ### Section 2 of EDA: Merged Income Limits and Insurance Product Availability Dataset for California Counties (2022–2023)

# %% [markdown]
# #### What We Learned From This EDA from Dataset #2 and Dataset #4
#
# Through EDA, we examined the relationship between county-level income limits and the availability of health insurance products in California. By combining datasets on Area Median Income (AMI) and the number of insurance plans offered by zip code, we visualized how economic conditions connect with healthcare access.
#
#
# Our scatter plot showed that counties with higher AMI generally offer more health insurance options. A boxplot comparing high-income and low-income counties added on to this finding, showing a significant gap in average product availability. These patterns suggest that residents in lower-income areas may experience less access to mental health-related insurance resources. These two datasets help guide our broader analysis of disparities in mental health care across the state.

# %% [markdown]
# #### How These Datasets Connect
#
#
# The income limits dataset provides economic context by reporting Area Median Income (AMI) and standardized income brackets (e.g., Acutely Low Income, Very Low Income) for each California county. This allowed us to identify which counties fall into higher or lower income categories based on official thresholds.
#
#
# The second dataset tracks how many health insurance products are available in each zip code, which we aggregated to the county level. This gives us a proxy for how much healthcare choice, and by extension, mental health access is available in each region.
#
#
# By merging these two datasets using county as a common factor, we were able to analyze whether income level influences access to health insurance plans. This merged dataset directly supports our research question about whether lower-income neighborhoods face reduced access to mental health care.

# %%
#STEP 1 & 2:
import pandas as pd


# Load the datasets
df_insurance = pd.read_csv("data/CAProductByZip.csv")
df_zip_ref = pd.read_csv("data/cazipcodes.csv")


# Drop duplicate zip codes and make an explicit copy
df_insurance_unique = df_insurance.drop_duplicates(subset="Zip Code", keep="first").copy()


# Standardize zip code formats to 5 digits
df_insurance_unique['Zip Code'] = df_insurance_unique['Zip Code'].astype(str).str.zfill(5)
df_zip_ref['zip'] = df_zip_ref['zip'].astype(str).str.zfill(5)


# Rename 'zip' column to match for merging
df_zip_ref_renamed = df_zip_ref.rename(columns={'zip': 'Zip Code'})


# Merge the insurance and zip reference datasets on Zip Code
df_merged = pd.merge(df_insurance_unique, df_zip_ref_renamed, on='Zip Code', how='inner')


# Preview
print(f"Merged dataset shape: {df_merged.shape}")
df_merged.head()
# Out:
# Merged dataset shape: (1802, 26)
#    Covered California Rating Region  County  FIPS County Code Zip Code  \
# 0                                 1  ALPINE                 3    95646
# 1                                 1  ALPINE                 3    96120
# 2                                 1  AMADOR                 5    95601
# 3                                 1  AMADOR                 5    95629
# 4                                 1  AMADOR                 5    95640
#
#   Zip Code Split Across Counties  Aetna HMO  Anthem EPO  Anthem HMO  \
# 0                                       NaN         6.0         NaN
# 1                                       NaN         6.0         NaN
# 2                                       NaN         6.0         NaN
# 3                              X        NaN         6.0         NaN
# 4                                       NaN         6.0         NaN
#
#    Blue Shield HMO  Blue Shield PPO  ...  Molina HMO  Sharp HMO 1 (Copay)  \
# ...

# %%
# STEP 3: Calculate Total Health Insurance Products per Zip Code


# List of columns that represent available health insurance plans
product_columns = [
    'Aetna HMO', 'Anthem EPO', 'Anthem HMO', 'Blue Shield HMO',
    'Blue Shield PPO', 'Chinese Community HMO', 'Health Net HMO',
    'Health Net PPO', 'IEHP HMO', 'Kaiser HMO', 'LA Care HMO',
    'Molina HMO', 'Sharp HMO 1 (Copay)', 'Sharp HMO 2 (Coin)',
    'Valley HMO', 'Western Health HMO'
]


# Convert all non-null entries in product columns to 1, nulls to 0
# This creates a binary indicator for whether a product is offered
df_merged[product_columns] = df_merged[product_columns].notna().astype(int)


# Calculate the total number of products offered in each zip code
df_merged['Total Products'] = df_merged[product_columns].sum(axis=1)


# Create a cleaned DataFrame with just the info we need
df_total_products = df_merged[['Zip Code', 'county', 'Total Products']]


# Preview the result
df_total_products.head()
# Out:
#   Zip Code         county  Total Products
# 0    95646  Alpine County               2
# 1    96120  Alpine County               2
# 2    95601  Amador County               2
# 3    95629  Amador County               2
# 4    95640  Amador County               3

# %%
# STEP 4: Group by County to calculate average number of products per zip code


# Group zip-level product totals to the county level
df_products_by_county = df_total_products.groupby('county')['Total Products'].mean().reset_index()


# Rename column for clarity
df_products_by_county = df_products_by_county.rename(columns={'Total Products': 'Avg Products Per Zip'})


# Preview the result
df_products_by_county.head()
# Out:
#              county  Avg Products Per Zip
# 0    Alameda County              5.000000
# 1     Alpine County              2.000000
# 2     Amador County              2.181818
# 3      Butte County              2.000000
# 4  Calaveras County              2.000000

# %%
#STEP 5: Combine two datasets and cleaning needed 
# Reload combined income data (if needed)
df_combined = pd.concat([df_2022, df_2023], ignore_index=True)


# Rename 'County' column for merging
df_combined_renamed = df_combined.rename(columns={'County': 'county'})


# Fix mismatch: Add " County" to county names to match insurance dataset
df_combined_renamed['county'] = df_combined_renamed['county'].astype(str) + " County"


# Merge on county
df_merged_final = pd.merge(df_combined_renamed, df_products_by_county, on='county', how='left')


# Preview
df_merged_final[['county', 'Year', 'AMI', 'Avg Products Per Zip']].head()
# Out:
#              county  Year     AMI  Avg Products Per Zip
# 0    Alameda County  2022  142800              5.000000
# 1     Alpine County  2022   94900              2.000000
# 2     Amador County  2022   86600              2.181818
# 3      Butte County  2022   85000              2.000000
# 4  Calaveras County  2022   90000              2.000000

# %%
# STEP 6: Scatterplot 


# Separate by year
df_2022 = df_merged_final[df_merged_final['Year'] == 2022]
df_2023 = df_merged_final[df_merged_final['Year'] == 2023]


# Create scatterplot
plt.figure(figsize=(10, 6))
plt.scatter(df_2022['AMI'], df_2022['Avg Products Per Zip'], color='blue', alpha=0.6, label='2022')
plt.scatter(df_2023['AMI'], df_2023['Avg Products Per Zip'], color='red', alpha=0.6, label='2023')


# Add labels
plt.title("AMI vs. Avg Insurance Products per Zip Code")
plt.xlabel("Area Median Income (AMI)")
plt.ylabel("Average Products per Zip Code")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Create a new column to categorize counties by income level
ami_median = df_merged_final['AMI'].median()
df_merged_final['Income Group'] = df_merged_final['AMI'].apply(
    lambda x: 'Low Income' if x < ami_median else 'High Income'
)


# Create boxplot: Average insurance products per zip code by income group
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 6))


low_income = df_merged_final[df_merged_final['Income Group'] == 'Low Income']['Avg Products Per Zip']
high_income = df_merged_final[df_merged_final['Income Group'] == 'High Income']['Avg Products Per Zip']


plt.boxplot([low_income.dropna(), high_income.dropna()], labels=['Low Income', 'High Income'])
plt.title('Avg Insurance Products per Zip by Income Group')
plt.ylabel('Average Products per Zip Code')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/jx/dr80n_1n4s3flx3lb29pzrl00000gn/T/ipykernel_58589/1876860957.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([low_income.dropna(), high_income.dropna()], labels=['Low Income', 'High Income'])

# %% [markdown]
# This boxplot compares average health insurance product availability between low-income and high-income counties. The results clearly show that high-income counties tend to offer a wider variety of insurance options, with a higher median and broader distribution. In contrast, low-income counties are experiencing lower availability of health insurance options. This visualization supports our hypothesis that income level is positively associated with access to healthcare resources like insurance coverage.

# %% [markdown]
# ### Section 3 of EDA: Healthcare Products vs. Median Household Income Census by Zipcode

# %%
#merge healthcare product count with income data by Zip Code
df_total_products['Zip Code'] = df_total_products['Zip Code'].astype(int)
eda_df = df_total_products.merge(zip_data[['median_hh_income_total']], left_on='Zip Code', right_index=True)


#drop any missing values
eda_df = eda_df.dropna(subset=['median_hh_income_total', 'Total Products'])


#check data
eda_df
# Out:
# /var/folders/jx/dr80n_1n4s3flx3lb29pzrl00000gn/T/ipykernel_58589/3178190800.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total_products['Zip Code'] = df_total_products['Zip Code'].astype(int)
#       Zip Code            county  Total Products  median_hh_income_total
# 0        95646     Alpine County               2                145341.0
# 1        96120     Alpine County               2                100909.0
# 2        95601     Amador County               2                 91233.0
# 4        95640     Amador County               3                 94045.0
# 5        95642     Amador County               2                 85000.0
# ...        ...               ...             ...                     ...
# ...

# %%
#plot kde plot of health care products vs household income 
plt.figure(figsize=(10, 6))
sns.kdeplot(data=eda_df, x='median_hh_income_total', hue='Total Products', palette='viridis', common_norm=False)
plt.title('Income Distribution by Product Count')
plt.xlabel('Median Household Income')
plt.show()

# %%
#Create 10 bins
bins = list(range(0, 11))  #0-10
labels = [f'{i}' for i in range(0, 10)]  #labels bins: 0-9


#bin Total Products into 10 bins
eda_df['Product Bins'] = pd.cut(eda_df['Total Products'], bins=bins, labels=labels, right=False, include_lowest=True)


#drop any incomplete data
eda_df_filtered = eda_df.dropna(subset=['Product Bins'])


#create income bins ~ 10 for simplicity
income_bins = pd.cut(eda_df['median_hh_income_total'], bins=10)  


#add to income bins to dataframe
eda_df['Income Bin'] = income_bins


#generate heatmap from total products and the 10 income bins by zip
heatmap_data = eda_df.pivot_table(index='Total Products',columns='Income Bin',values='Zip Code',aggfunc='count',fill_value=0)


#plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, fmt='d', cmap='YlGnBu', cbar_kws={'label': 'Number of ZIP Codes'})


plt.title('Heatmap: Healthcare Products vs Median Household Income')
plt.xlabel('Median Household Income Range')
plt.ylabel('Total Healthcare Products')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/jx/dr80n_1n4s3flx3lb29pzrl00000gn/T/ipykernel_58589/1059106536.py:23: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   heatmap_data = eda_df.pivot_table(index='Total Products',columns='Income Bin',values='Zip Code',aggfunc='count',fill_value=0)

# %%
#find median household income
median_income = eda_df['median_hh_income_total'].median()


#Split into low and high income household groups
low_income_group = eda_df[eda_df['median_hh_income_total'] <= median_income]['Total Products']
high_income_group = eda_df[eda_df['median_hh_income_total'] > median_income]['Total Products']


#perform t-test between low and high income groups
t_stat, p_value = ttest_ind(low_income_group, high_income_group, equal_var=False)


#show results
print("T-Test Results:")
print(f"  T-statistic: {t_stat:.10f}")
print(f"  P-value: {p_value:.20f}")
if p_value < 0.05:
    print("Statistically significant difference: Income level is associated with the number of healthcare products.")
else:
    print("Not statistically significant difference: Income level is not associated with the number of products.")
# Out:
# T-Test Results:
#   T-statistic: -9.8653328149
#   P-value: 0.00000000000000000000
# Statistically significant difference: Income level is associated with the number of healthcare products.

# %%
#show visual of low income vs high income health care products
eda_df['Income Group'] = np.where(eda_df['median_hh_income_total'] > median_income, 'High Income', 'Low Income')


plt.figure(figsize=(8, 6))
sns.boxplot(data=eda_df, x='Income Group', y='Total Products', palette='pastel')
plt.title('Healthcare Products by Income Group')
plt.ylabel('Total Products')
plt.xlabel('Income Group')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/jx/dr80n_1n4s3flx3lb29pzrl00000gn/T/ipykernel_58589/2704652700.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=eda_df, x='Income Group', y='Total Products', palette='pastel')

# %% [markdown]
# The healthcare products offered vs median household income using a density plot shows a positive correlation between income and number of healthcare products offered, as zip codes with fewer products are skewed towards the lower income side, and as the number of products increases, the peak of the income distribution shifts towards the right, indicating higher household incomes. While the heatmap shows that fewer products are offered at lower to mid income ranges while a higher product count is offered at higher income ranges, i.e. 7-9 products are offered more frequently at higher income brackets. When checking the relationship between healthcare products offered vs median household income statistically using a t-test and p-value, we find that zip codes classified below the median income had a lower product availability (less than 5), while zip codes classified with above median income had a higher product availability (over 6). The t-test value was -8.498, this value is negative since the lower income zip code areas had lower product availability than the higher income zip codes. While the p-value (4.45x10^-17) was much smaller than 0.001, indicating that the chance of observing this difference by a random chance is very low. This provides evidence that higher-income zip codes have access to more healthcare products on average.

# %% [markdown]
# ### Section 4 of EDA: Therapist by Zip Code in California vs. California County Income Limits
#
# Some more words and stuff. Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
# Load both income datasets
income_2022 = pd.read_csv("data/2022-income-limits.csv")
income_2023 = pd.read_csv("data/2023-income-limits.csv")


# Add Year column
income_2022['Year'] = 2022
income_2023['Year'] = 2023


# Standardize county column
income_2022['County'] = income_2022['County'].str.strip().str.lower()
income_2023['County'] = income_2023['County'].str.strip().str.lower()


# Combine both datasets
income_combined = pd.concat([income_2022, income_2023], ignore_index=True)
income_combined
# Out:
#         County     AMI  ALI_1  ALI_2  ALI_3  ALI_4  ALI_5  ALI_6  ALI_7  \
# 0      alameda  142800  15000  17100  19250  21400  23100  24800  26550
# 1       alpine   94900  10000  11400  12850  14250  15400  16550  17650
# 2       amador   86600   9100  10400  11700  13000  14050  15100  16100
# 3        butte   85000   8950  10200  11500  12750  13750  14800  15800
# 4    calaveras   90000   9450  10800  12150  13500  14600  15650  16750
# ..         ...     ...    ...    ...    ...    ...    ...    ...    ...
# 111     tulare   83800   8800  10050  11300  12550  13550  14550  15550
# 112   tuolumne   97700  10250  11700  13200  14650  15800  17000  18150
# 113    ventura  123500  13000  14850  16700  18550  20050  21500  23000
# 114       yolo  114000  11950  13700  15400  17100  18450  19850  21200
# 115       yuba   83800   8800  10050  11300  12550  13550  14550  15550
#
#      ALI_8  ...    LI_8   MOD_1   MOD_2   MOD_3   MOD_4   MOD_5   MOD_6  \
# ...

# %%
# Read the input file
psych_df = pd.read_csv("data/Psychology_Data00.xls", sep='\t')


# Filter rows where 'License Type' contains 'Psychologist'
psychologists = psych_df[psych_df['License Type'].str.contains('Psychologist', case=False, na=False)]


# Filter to only include psychologists in the state of California
psychologists_ca = psychologists[psychologists['State'] == 'CA']


# Select only 'Zip' and 'County' columns, fill missing values with '0'
df_selected = psychologists_ca[['Zip', 'County']].copy().fillna('0')


# Clean the Zip codes: ensure they are 5-digit strings
df_selected['Zip'] = df_selected['Zip'].astype(str).str[:5]


# Standardize column names to lowercase
df_selected.columns = df_selected.columns.str.lower()


# Group by 'zip' and 'county', and count number of psychologists in each zip+county combination
psychologists_by_zip = df_selected.groupby(['zip', 'county']).size().reset_index(name='psychologist_count')


# Further group by county: sum the number of psychologists across all zip codes within each county
psychologists_by_county = psychologists_by_zip.groupby('county')['psychologist_count'].sum().reset_index()


# Clean up county names: strip leading/trailing spaces and convert to lowercase
psychologists_by_county['county'] = psychologists_by_county['county'].str.strip().str.lower()

# %%
# Merge all datasets
merged_all = pd.merge(income_combined, psychologists_by_county, left_on='County', right_on='county', how='inner')
merged_all = merged_all.drop(columns=['county'])


# Get top 5 counties with highest number of psychologists
top_counties = (
    merged_all.groupby('County')['psychologist_count'].mean()
    .sort_values(ascending=False)
    .head(5)
    .index.tolist()
)

# Filter merged dataset to include only top counties
filtered_df = merged_all[merged_all['County'].isin(top_counties)]
filtered_df
# Out:
#            County     AMI  ALI_1  ALI_2  ALI_3  ALI_4  ALI_5  ALI_6  ALI_7  \
# 0         alameda  142800  15000  17100  19250  21400  23100  24800  26550
# 17    los angeles   91100   9550  10900  12300  13650  14750  15850  16950
# 28         orange  119100  12500  14300  16050  17850  19300  20700  22150
# 35      san diego  106900  11250  12850  14450  16050  17350  18600  19900
# 36  san francisco  166000  17450  19900  22400  24900  26900  28900  30900
# 56        alameda  147900  15550  17750  20000  22200  24000  25750  27550
# 73    los angeles   98200  10350  11800  13300  14750  15950  17100  18300
# 84         orange  127800  13400  15300  17250  19150  20700  22200  23750
# 91      san diego  116800  12250  14000  15750  17500  18900  20300  21700
# 92  san francisco  175000  18400  21000  23650  26250  28350  30450  32550
#
#     ALI_8  ...   MOD_1   MOD_2   MOD_3   MOD_4   MOD_5   MOD_6   MOD_7  \
# ...

# %%
# Create Scatter Plot: AMI vs Psychologist Count
plt.figure(figsize=(10, 6))
sns.scatterplot(data=merged_all, x='AMI', y='psychologist_count', hue='Year', palette='Set2')
plt.title('AMI vs Psychologist Count by Year')
plt.xlabel('Area Median Income (AMI)')
plt.ylabel('Psychologist Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# This scatter plot visualizes the relationship between the Area Median Income (AMI) and the number of psychologists across California counties in 2022 and 2023. It helps us assess whether higher-income counties tend to have more psychologists available. By including the 'Year' hue, we can observe how this relationship changes over time and how the AMI of different California counties affect their access to psychologists .

# %%
# Create Bar Plot: Top 10 Counties by Psychologist Count
top_10 = merged_all.sort_values(by='psychologist_count', ascending=False).head(10)


plt.figure(figsize=(12, 6))
sns.barplot(data=top_10, x='County', y='psychologist_count', palette='Blues_d')
plt.title("Top 10 California Counties by Number of Psychologists")
plt.xlabel("County")
plt.ylabel("Number of Psychologists")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/jx/dr80n_1n4s3flx3lb29pzrl00000gn/T/ipykernel_58589/605739625.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_10, x='County', y='psychologist_count', palette='Blues_d')

# %% [markdown]
# This bar plot shows the top 10 California counties with the highest number of licensed psychologists. The goal is to highlight the geographic disparities in the availability of mental health professionals, identifying which counties may have more robust access to psychological services.

# %%
# Filter to top counties
subset = merged_all[merged_all['County'].isin(top_counties)]


# Create Grouped Bar Plot: AMI per year for each county
plt.figure(figsize=(12, 6))
sns.barplot(data=subset, x='County', y='AMI', hue='Year', palette='Set2')
plt.title('AMI by Year for Top 5 Counties')
plt.ylabel('Area Median Income')
plt.xlabel('County')
plt.tight_layout()
plt.show()

# %% [markdown]
# This grouped bar plot compares the Area Median Income (AMI) for the top 5 counties (by psychologist count) across the two years (2022 and 2023). It allows us to examine income trends in counties with high mental health professional density and observe whether economic shifts may be influencing psychologist availability or demand.

# %% [markdown]
# We merged two primary datasets to analyze the relationship between income levels and mental health provider availability, being psychologist count across California counties:
#
# **Income Limits Data (2022 & 2023)**
# - This dataset includes Area Median Income (AMI) and income thresholds (e.g., extremely low, low, moderate) for each county in California. By incorporating both 2022 and 2023 data, we can observe how income levels changed over time.
#
#
# **Psychologist Licensing Data**
# - This dataset provides ZIP-level information on licensed psychologists. We filtered the data to include only psychologists in California and then aggregated it by county to calculate the total number of psychologists per county.

# %% [markdown]
# By joining these datasets on the county field, we created a unified dataset (merged_all) that is a direct comparison between income levels and psychologist counts. This merged data allows us to answer key questions, such as:
# - Do higher-income counties have more psychologists?
#
#
# - Have income levels increased from 2022 to 2023 and have these correlated changes affected mental health access?
#
#
# - Which counties might be underserved in relation to their economic status?

# %% [markdown]
# The merged dataset enables both a year over year and county by county analysis. Visualizations like the scatter plots and bar plots, reveal patterns that suggest income may be associated with the distribution of mental health resources such as psychologist counts within California counties, however it doesn’t seem that it is the leading factor to this access.

# %% [markdown]
# ### Section 5 of EDA: California Licensed MHRCs and PHFs vs. California County Income Limits or ACS data

# %%
sns.histplot(df_zip, x="capacity")
plt.xlabel("Large Facility Max Capacity")
plt.title("Histogram of Max Facility Capacity (by Zip Code)")
plt.show()
sns.histplot(psychologists_by_zip, x="psychologist_count")
plt.xlabel("Number of Psychologists")
plt.title("Histogram of Psychologist Count (by Zip Code)")
plt.show()
sns.histplot(df_total_products, x="Total Products")
plt.xlabel("Total Available Products")
plt.title("Histogram of Total Available Products (by Zip Code)")
plt.show()

# merge all psychologist dataframes (psychologist count, total mental health products, facility capacity)

df_zip['zip'] = df_zip['zip'].astype(int)
psychologists_by_zip['zip'] = psychologists_by_zip['zip'].astype(int)
df_total_products.rename(columns={"Zip Code": "zip"}, inplace=True)
df_total_products['zip'] = df_total_products['zip'].astype(int)

df_pccap = pd.merge(df_zip, psychologists_by_zip, on="zip")
df_pccap = pd.merge(df_pccap, df_total_products, on="zip")
df_pccap

# correlation between all graphs

sns.lmplot(data=df_pccap, x="capacity", y="psychologist_count", line_kws={'color': 'red'})
plt.show()
sns.lmplot(data=df_pccap, x="capacity", y="Total Products", line_kws={'color': 'red'})
plt.show()
sns.lmplot(data=df_pccap, x="Total Products", y="psychologist_count", line_kws={'color': 'red'})
plt.show()
# Out:
# /var/folders/jx/dr80n_1n4s3flx3lb29pzrl00000gn/T/ipykernel_58589/1410081506.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total_products.rename(columns={"Zip Code": "zip"}, inplace=True)
# /var/folders/jx/dr80n_1n4s3flx3lb29pzrl00000gn/T/ipykernel_58589/1410081506.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total_products['zip'] = df_total_products['zip'].astype(int)

# %% [markdown]
# The purpose of this section of EDA is to cross-validate our data on the mental health quality side. We understand that the larger question that we are asking is whether higher income correlates with better psychological care, and to that extent it is important to cross-validate our data. This is why we make sure that we compare scatter plots of different ways to evaluate quality of mental health care.
#
# The three datasets that we used in this EDA are the dataset that measures the count of psychologists (Dataset #4), the dataset that measures available products (Dataset #5), and the dataset of California maximum capacity of large mental health care facilities by county, normalized to give all zip codes within that county the same number (Dataset #6). We see a positive correlation (although weak) between all three datasets. The weak correlation is to be expected, since our Dataset #6 suffers from a lack of observations in the original dataset, and Dataset #5 suffers from lack of bins. The fact that we see a positive slope despite that is a good sign that we can trust our data.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# The project proposes a study on mental health, which is already considered a sensitive issue for many people. Furthermore, the project is based very heavily on geolocation (most likely via zip codes), and it’s possible that it may reinforce stereotypes; a lot of care should be taken to avoid sweeping generalizations, since it is not a good idea to make social comments in answering a question like this.
#
# - Firstly, there’s a possibility that the hypothesis itself could be misconstrued (i.e. just because someone has access to less money doesn’t necessarily mean that they have access to worse healthcare, or just because someone is rich doesn’t mean that they cannot have mental health issues).
#
# - Secondly, scraping data involves coming into contact with very sensitive and possibly identifiable information. Many people are sensitive about how much they earn, and even scraping therapist listings might get us information that we do not necessarily need.
#
# - Thirdly, there may be problems with taking typical values such as mean or median as representative of income. There may be massive variance in income within even a single zip code, and this could skew our findings to the wrong conclusion, which could be misused.
#
#
#
# In the same order as the problems were listed:
#
# - We will have to be very careful with the words we use, and make sure not to bring any outside factors outside of what exactly we are using to make our hypothesis and conclusions (e.g. mean/median house prices or avg., count of therapists in a zip code, etc.)
#
# - For problems regarding privacy, it is our duty to make sure to drop any data that we are not using as soon as possible, and avoid using fringe data in our analysis. We should do exactly what our hypothesis and proposal are set out to do, and we should avoid testing the effect of a variety of different factors so that we do not encounter a facetious relationship based purely on the number of relationships that we want and check.
#
# - Since the problem is with typical values, we could consider stratifying our data to account for neighborhoods with high and low variance respectively (e.g. separate bins for rich neighborhoods, poor neighborhoods, and hybrid neighborhoods)

# %% [markdown]
# **Are there any biases/privacy/terms of use issues with the data you proposed?**
#
# - As mentioned before, data may include personally identifiable information about therapists or house owners, which is a sensitive issue.
#
# **Are there potential biases in your dataset(s), in terms of who it composes, and how it was collected, that may be problematic in terms of it allowing for equitable analysis? (For example, does your data exclude particular populations, or is it likely to reflect particular human biases in a way that could be a problem?)**
#
# - The data may be problematic because census data may exclude homeless populations, which would not be represented on such a dataset. It may also not accurately represent the renting population of the area.
#
# **How will you set out to detect these specific biases before, during, and after/when communicating your analysis?**
#
# - Before analysis, we could check for missing data or skew within specific zip codes. This could help us locate neighborhoods with large quantities of underrepresented homes and/or people. During analysis, we could stratify our data to account for different income groups. This could prevent outliers from shifting our results drastically. After analysis, we could review with our peers to make sure that we have accounted for all issues that we have mentioned and not mentioned, and make sure that our wording is exact.
#
# **Are there any other issues related to your topic area, data, and/or analyses that are potentially problematic in terms of data privacy and equitable impact?**
#
# - As mentioned earlier, the data might unfairly misrepresent incomes and availability of mental health care within neighborhoods. It may not account for more informal mental health practices either, and it may create negative connotations about certain areas being more unfriendly to such practice.
#
# **How will you handle issues you identified?**
#
# - A lot of this is covered in points mentioned earlier. Additionally to those, however, we could also consider using additional data sources such as Census data to validate our data categories and make sure that any analysis we do is reasonable.

# %% [markdown]
# # Discusison and Conclusion
#
# Income level is a key variable that affects mental health resource access, with higher-income counties and zip codes showing more availability of licensed therapists and health insurance products. This shows broader socioeconomic trends where wealthier communities attract more providers and services due to higher reimbursement rates and demand.
#
# Despite there is a strong connection between income level and mental health access, it is not the only determining factor. Some low-income areas still showed moderate access, possibly due to local policy initiatives, county health investments, or nonprofit efforts. This means that better public health strategies can help improve the resource gap even in economically marginalized areas.
#
# Our data showed statistically significant differences in mental health resource availability between income groups, as supported by t-tests and visualizations like scatterplots and boxplots. These findings validate our hypothesis that income inequality correlates with health access inequality, but they also show us deeper structural issues beyond individual income alone.
#
# The relationship between income and access appears to be influenced by additional factors such as rural vs. urban location, population density, and possibly the presence of large healthcare systems or universities. These variables should be investigated in future studies to better understand the root causes of mental health resource disparity.
#
# Policymakers should also consider geography, infrastructure, insurance regulation, and workforce distribution when designing equitable mental health resources. True accessibility requires both financial affordability and service availability.
#
#
# # Team Contributions
#
# Speficy who did what.  This should be pretty granular, perhaps bullet points, no more than a few sentences per person.

# %% [markdown]
# Aileen Phuong
# - Found Datasets
# - Project Timeline
# - Cleaned, Merged, and Analysed Data
# - Abstract
# - Visuals for Video
#
# Arohan Mittal
# - Ethics and Privacy
# - Cleaned, Merged, and Analysed Data
# - Abstract
# - Video Presentation
#
# Genevieve Selsor
# - Found Datasets
# - Cleaned, Merged, and Analysed Data
# - Organized combined work to GitHub
# - Conclusion
# - Video Presentation
#
# Duong Ngo
# - Background Info/Hypothesis
# - Cleaned, Merged, and Analysed Data
# - Conclusion
# - Visuals for Video
#
# Ryan Christian Nalangan
# - Background Info/Hypothesis
# - Found Dataset
# - Cleaned, Merged, and Analysed Data
# - Conclusion
# - Video Recording/Submission
